# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishaw99/Revisting-Gemini/blob/main/Part_2_Thinking_Capability_and_Structured_Output.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STEP 1: Install the Google Generative AI SDK
# !pip install -q google-generativeai

import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyBX1pzoOTvngpkjzvf9bKx2s_RpIcrD_8A"

# %% [markdown]
# # THINKING

# %%
# New Gemini models are equipped with advanced reasoning capabilities and a structured thinking process.
# This significantly enhances their ability to handle complex tasks involving multi-step planning, such as coding, advanced mathematics,
# data analysis, and problem-solving.

# %%
# THOUGH SUMMARIES

# Imagine you're asking Gemini (or any smart AI) to solve a complex problem — like writing code, analyzing data, or planning steps for a task.
# As the model works on your request, it doesn't just give an answer out of nowhere. Internally, it "thinks" step-by-step,
# analyzing, reasoning, and deciding what to do next — similar to how a human might work through a math problem on paper
# before writing the final answer.
# These internal steps are called the model’s “thought summary ”.


from google import genai
client = genai.Client()

response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents="Explain photosynthesis with an analogy")

response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""Imagine a **Solar-Powered Bakery** that needs to make its own delicious food to survive and grow.
#
# Here's how the analogy breaks down:
#
# 1.  **The Plant = The Entire Bakery Operation**
#     *   The bakery is self-sufficient, just like a plant.
#
# 2.  **Chloroplasts (specifically Chlorophyll) = The Green Ovens & Special Machinery**
#     *   These are the specific parts within the plant's leaves (the bakery's kitchen) that have a magical green color. This green machinery is specially designed to absorb sunlight, just like a solar panel.
#
# 3.  **Sunlight = The Free, Powerful Solar Energy**
#     *   This is the electricity that powers the bakery! Without the sun's energy, the ovens can't turn on, and no baking can happen. It's the primary energy source.
#
# 4.  **Water (H2O) = The Essential Liquid Ingredient**
#     *   Think of it as the water needed for dough, batters, or to operate the mixing machines. It's brought in through the roots (the bakery's plumbing system).
#
# 5.  **Carbon Dioxide (CO2) = The "Flour" or Main Dry Ingredient from the Air**
#     *   This gas is absorbed from the air through tiny pores in the leaves (the bakery's ventilation system that brings in raw materials). It's the bulk ingredient that will be transformed into the final product.
#
# 6.  **Glucose (Sugar/Food for the plant) = The Delicious Baked Goods (Bread, Cakes, Cookies)**
#     *   This is the final, energy-rich product that the bakery creates. It's the fuel for the plant to grow, repair itself, and make fruits or flowers. Some of it is eaten immediately, some is stored for later.
#
# 7.  **Oxygen (O2) = The Wonderful Aroma & Steam Released as a Byproduct**
#     *   When you bake, a lovely smell and steam waft out of the oven and vents. This isn't the main product you're trying to make, but it's a natural and harmless (to us, beneficial!) byproduct of the baking process. The plant releases this oxygen into the air.
#
# ---
#
# **The Baking Process (Photosynthesis in Two Main Steps):**
#
# *   **Step 1: The "Energy Harvest" (Light-Dependent Reactions)**
#     *   The green ovens/machinery (chloroplasts/chlorophyll) **capture the sun's energy**. They use this energy to do two things:
#         *   **Split the water (H2O):** Releasing the oxygen (our "aroma") and creating tiny "energy tokens" or "charged batteries" (ATP and NADPH).
#         *   **Get the ovens hot:** Prepare everything for the main baking.
#
# *   **Step 2: The "Baking/Sugar Making" (Light-Independent Reactions / Calvin Cycle)**
#     *   Now, the bakery takes the **flour (CO2)** and, using the **energy tokens/charged batteries** from Step 1, starts assembling it, along with other basic ingredients. They work in a special cycle, just like a complex recipe.
#     *   Through this intricate process, the flour (CO2) is transformed into the **delicious baked goods (glucose)**.
#
# **In Short:** The solar-powered bakery uses free sunlight to power its green ovens, taking simple ingredients like water and "flour" (carbon dioxide) to bake delicious food (glucose) for itself, releasing a pleasant aroma (oxygen) into the atmosphere as it works."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='5yRPaZX2OpCS_uMPsZT_4A8',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=767,
#     prompt_token_count=6,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=6
#       ),
#     ],
#     thoughts_token_count=1228,
#     total_token_count=2001
#   )
# )

# %%
from google import genai
from google.genai import types
client = genai.Client()

response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents="Explain photosynthesis with an analogy"),
config= types.GenerateContentConfig(
      thinking_config= types.ThinkingConfig(
          include_thoughts=True
      )
  )

response
# Out:
# (GenerateContentResponse(
#    automatic_function_calling_history=[],
#    candidates=[
#      Candidate(
#        content=Content(
#          parts=[
#            Part(
#              text="""Okay, let's explain photosynthesis with the analogy of a **Solar-Powered Bakery**.
#
#  Imagine a plant is like a super-efficient, eco-friendly bakery.
#
#  **The Bakery Elements:**
#
#  1.  **The Plant:** This is the entire bakery building, with all its different rooms and equipment.
#  2.  **The Leaves:** These are the main kitchen and production floor of the bakery, where most of the magic happens.
#  3.  **Chloroplasts:** These are the special, tiny, green ovens and baking stations *inside* the kitchen (leaves). They are the actual manufacturing units.
#  4.  **Chlorophyll:** This is the *solar panel system* installed on the roof of the bakery, but also integrated into the ovens themselves. It's what gives the kitchen its green color and, most importantly, it's specifically designed to *capture sunlight*.
#
#  **The Ingredients & Energy (Inputs):**
#
#  1.  **Sunlight:** This is the **free, renewable electricity** that powers the entire bakery. The solar panels (chlorophyll) are constantly absorbing this energy. Without it, the bakery can't run.
#  2.  **Water (H2O):** This is a key **ingredient** for the baking process, like water used to make dough. The plant's roots deliver this to the leaves (kitchen).
#  3.  **Carbon Dioxide (CO2):** This is the main **bulk ingredient**, like the sacks of flour delivered to the bakery. The plant absorbs this from the air through tiny openings in its leaves.
#
#  **The Baking Process (The Two Stages):**
#
#  **Stage 1: The Energy Harvest & Initial Prep (Light-Dependent Reactions)**
#
#  *   The solar panels (chlorophyll) capture the sun's electricity (light energy).
#  *   This electricity is used to power some initial machines. One of these machines takes the incoming water (H2O) and *splits it*.
#  *   When water is split, a component is used, and **Oxygen (O2)** is released as a *byproduct* or "exhaust steam" from this initial process. The bakery doesn't need this steam, so it's vented out into the air.
#  *   The captured solar energy, along with components from the water, is used to create **"charged batteries" or "energy tokens" (ATP and NADPH)**. These are not the final product, but they are crucial for powering the *next* stage of baking.
#
#  **Stage 2: The Sugar Production (Light-Independent Reactions / Calvin Cycle)**
#
#  *   Now, the bakery has its bulk ingredient (flour/CO2) and its "charged batteries" (ATP/NADPH) filled with energy.
#  *   These "charged batteries" provide the power and specific components needed to take the incoming flour (CO2) and *bake it*.
#  *   Inside the special ovens (chloroplasts), the flour (CO2) is transformed, using the energy from the "batteries."
#  *   The result is the bakery's delicious final product: **Glucose (sugar)**. This is like fresh-baked bread, cakes, or cookies!
#
#  **The Outputs:**
#
#  1.  **Glucose (Sugar):** This is the **food** the plant makes for itself. It uses this sugar for energy to grow, repair, and reproduce. Any extra can be stored as starch (like storing extra bread in the pantry).
#  2.  **Oxygen (O2):** As mentioned, this is the "exhaust steam" from the initial energy harvesting. The plant doesn't need it, so it **releases it into the atmosphere**, which is super handy for us!
#
#  **In Summary:**
#
#  The plant, like a solar-powered bakery, takes free solar energy, water, and carbon dioxide, and through a two-stage process (energy harvest and sugar production), bakes its own food (glucose) while releasing oxygen as a byproduct. It's the ultimate sustainable food factory, making life on Earth possible!"""
#            ),
#          ],
#          role='model'
#        ),
#        finish_reason=<FinishReason.STOP: 'STOP'>,
#        index=0
#      ),
#    ],
#    model_version='gemini-2.5-flash',
#    response_id='JShPacGvGZuM_PUPnYi0iQ8',
#    sdk_http_response=HttpResponse(
#      headers=<dict len=10>
#    ),
#    usage_metadata=GenerateContentResponseUsageMetadata(
#      candidates_token_count=843,
#      prompt_token_count=6,
#      prompt_tokens_details=[
#        ModalityTokenCount(
#          modality=<MediaModality.TEXT: 'TEXT'>,
#          token_count=6
#        ),
#      ],
#      thoughts_token_count=1496,
#      total_token_count=2345
#    )
#  ),)

# %%
print(response.text)
# Out:
# Isaac Newton, Albert Einstein, and Niels Bohr represent three distinct epochs and paradigm shifts in the history of physics. Each, in their own right, fundamentally altered our understanding of the universe, from the macroscopic to the quantum realm.
#
# Let's compare their scientific contributions and highlight how each shaped physics:
#
# ---
#
# ## 1. Sir Isaac Newton (1643 – 1727)
#
# **Era:** Classical Physics, The Scientific Revolution
#
# **Key Contributions:**
#
# 1.  **Laws of Motion:** Newton formulated three fundamental laws that describe the relationship between a body and the forces acting upon it, and its motion in response to those forces. These are the bedrock of classical mechanics.
#     *   **First Law (Inertia):** An object at rest stays at rest and an object in motion stays in motion with the same speed and in the same direction unless acted upon by an unbalanced force.
#     *   **Second Law (F=ma):** The acceleration of an object as produced by a net force is directly proportional to the magnitude of the net force, in the same direction as the net force, and inversely proportional to the mass of the object.
#     *   **Third Law (Action-Reaction):** For every action, there is an equal and opposite reaction.
# 2.  **Law of Universal Gravitation:** He described gravity as a universal force of attraction between any two objects with mass, proportional to the product of their masses and inversely proportional to the square of the distance between their centers ($F = G \frac{m_1 m_2}{r^2}$). This law unified terrestrial and celestial mechanics, explaining phenomena from falling apples to planetary orbits.
# 3.  **Calculus:** Co-invented (with Leibniz) differential and integral calculus, providing the mathematical tools necessary to describe continuous change and motion, which were essential for his physical theories.
# 4.  **Optics:** Conducted extensive experiments with light, demonstrating that white light is composed of a spectrum of colors and proposing a corpuscular (particle) theory of light. He also invented the reflecting telescope.
# 5.  **Principia Mathematica:** His magnum opus, published in 1687, laid out his laws of motion and gravitation with unprecedented mathematical rigor, establishing the scientific method and predictive power of mathematical physics.
#
# **How he Shaped Physics:**
#
# *   **Unified the Cosmos:** Newton single-handedly reconciled the physics of the heavens with the physics of the Earth, showing that the same laws governed both celestial bodies and everyday objects. This was a monumental intellectual achievement.
# *   **Foundation of Classical Physics:** His laws of motion and gravitation formed the bedrock of classical physics for over two centuries, allowing for precise predictions of the motion of objects, planets, and even the tides.
# *   **Deterministic Universe:** Newtonian physics fostered a worldview where the universe was seen as a giant, predictable clockwork mechanism. Given the initial conditions, the future state of the universe could, in principle, be calculated.
# *   **Mathematical Rigor:** He established the paradigm of using sophisticated mathematics (like calculus) to formulate physical laws and derive testable predictions, setting a new standard for scientific inquiry.
# *   **Empirical and Theoretical Synthesis:** Newton was a master of both meticulous observation and bold theoretical construction, demonstrating the power of integrating both approaches in science.
#
# ---
#
# ## 2. Albert Einstein (1879 – 1955)
#
# **Era:** Modern Physics, Relativity and the Early Quantum Era
#
# **Key Contributions:**
#
# 1.  **Special Theory of Relativity (1905):** Based on two postulates:
#     *   The laws of physics are the same for all observers in uniform motion relative to one another (principle of relativity).
#     *   The speed of light in a vacuum is the same for all inertial observers, regardless of the motion of the light source.
#     This led to revolutionary concepts like:
#     *   **Time Dilation:** Time passes differently for observers in relative motion.
#     *   **Length Contraction:** Objects appear shorter in their direction of motion.
#     *   **Mass-Energy Equivalence ($E=mc^2$):** Mass and energy are interchangeable, demonstrating that a small amount of mass can be converted into a vast amount of energy.
#     *   **No Absolute Simultaneity:** Events simultaneous for one observer may not be for another.
# 2.  **General Theory of Relativity (1915):** An extension of special relativity, incorporating gravity.
#     *   **Gravity as Spacetime Curvature:** Instead of a force, Einstein described gravity as a manifestation of the curvature of spacetime caused by mass and energy. Objects follow the curves in spacetime, not being pulled by a force.
#     *   **Equivalence Principle:** The effects of gravity are indistinguishable from the effects of acceleration.
#     *   Predicted phenomena like gravitational lensing, black holes, and gravitational waves (later confirmed).
# 3.  **Photoelectric Effect (1905):** Explained that light consists of discrete packets of energy called "quanta" or photons, which are absorbed or emitted in whole units. This work earned him the Nobel Prize in Physics in 1921 and was a crucial early contribution to quantum theory, despite his later discomfort with its probabilistic nature.
# 4.  **Brownian Motion (1905):** Provided a theoretical explanation for the seemingly random movement of particles suspended in a fluid, confirming the existence of atoms and molecules and providing a method to estimate their size.
# 5.  **Quantum Theory of Heat Capacity:** Contributed to understanding the specific heat of solids at low temperatures using quantum principles.
#
# **How he Shaped Physics:**
#
# *   **Overthrew Newtonian Absolutes:** Einstein shattered Newton's concepts of absolute space and absolute time, replacing them with a dynamic, interconnected spacetime that is relative to the observer's motion.
# *   **New Understanding of Gravity:** Transformed gravity from a mysterious force into a geometric property of spacetime itself, leading to modern cosmology and the study of extreme gravitational phenomena.
# *   **Opened the Quantum Door (Reluctantly):** While he later became a critic of quantum mechanics, his work on the photoelectric effect was a foundational pillar, establishing the quantum nature of light and opening the door to understanding the subatomic world.
# *   **Cosmological Impact:** General Relativity provided the framework for understanding the large-scale structure and evolution of the universe, leading to theories like the Big Bang.
# *   **Energy and Matter Equivalence:** His $E=mc^2$ equation profoundly changed our understanding of the relationship between mass and energy, with vast implications for nuclear physics and energy generation.
#
# ---
#
# ## 3. Niels Bohr (1885 – 1962)
#
# **Era:** Quantum Physics, The Atomic Age
#
# **Key Contributions:**
#
# 1.  **Bohr Model of the Atom (1913):** Proposed a revolutionary model for the hydrogen atom (and later extended to other atoms) that applied quantum mechanics to the structure of the atom. Key postulates included:
#     *   Electrons orbit the nucleus in specific, stable "stationary states" or energy levels without radiating energy.
#     *   Electrons can only jump between these discrete energy levels by absorbing or emitting photons of specific energies, equal to the difference between the energy levels ($E_f - E_i = hf$).
#     *   The angular momentum of an electron in an orbit is quantized ($L = n \frac{h}{2\pi}$).
#     This model successfully explained the discrete spectral lines of hydrogen.
# 2.  **The Copenhagen Interpretation of Quantum Mechanics:** Developed (with Werner Heisenberg and others) the most widely accepted interpretation of quantum mechanics. Its key tenets include:
#     *   **Wave-Particle Duality:** Quantum entities exhibit characteristics of both waves and particles.
#     *   **Probability:** The outcomes of quantum events are inherently probabilistic, not deterministic.
#     *   **Uncertainty Principle:** It is impossible to simultaneously know with perfect precision certain pairs of properties of a particle (e.g., position and momentum).
#     *   **Role of the Observer:** The act of measurement "collapses" the wave function, forcing a quantum system into a definite state.
# 3.  **Complementarity Principle:** Proposed that certain properties of quantum objects, such as wave and particle behavior, are complementary; they cannot be observed simultaneously but are both necessary for a complete description of the phenomenon.
# 4.  **Nuclear Fission Theory:** Made significant contributions to understanding nuclear fission, particularly the liquid drop model of the nucleus.
#
# **How he Shaped Physics:**
#
# *   **Bridged Classical and Quantum:** Bohr's model was a crucial stepping stone, incorporating quantum ideas into the structure of the atom while still retaining some classical concepts (like orbits). It provided the first successful quantum explanation of atomic structure and spectra.
# *   **Atomic Structure and Chemistry:** His model laid the foundation for understanding atomic structure, explaining the chemical properties of elements and the periodic table.
# *   **Philosophical Implications of Quantum Mechanics:** Bohr was a profound thinker about the philosophical implications of quantum theory. The Copenhagen Interpretation profoundly changed our understanding of reality, causality, and the role of the observer in physics.
# *   **Shift to Probabilistic Universe:** Unlike Newton's deterministic universe or Einstein's geometric one, Bohr's quantum world introduced inherent uncertainty and probability as fundamental aspects of reality at the smallest scales, which many physicists (including Einstein) struggled to accept.
# *   **Modern Quantum Theory:** While the Bohr model was eventually superseded by more sophisticated quantum mechanics (like Schrödinger's equation), it was the essential conceptual leap that paved the way for the full development of quantum field theory and our understanding of particle physics.
#
# ---
#
# ## Conclusion: An Evolving Tapestry of Reality
#
# These three titans of physics represent a continuous evolution of our understanding of the universe:
#
# *   **Newton** gave us a **deterministic, mechanistic universe** governed by universal forces and mathematical laws, unifying the terrestrial and celestial realms. He provided the framework for classical physics that was incredibly successful for centuries.
# *   **Einstein** revolutionized our understanding of space, time, gravity, and the very fabric of the cosmos, showing a **relative, interconnected spacetime** where gravity is geometry. He introduced concepts that pushed Newton's classical view to its limits and into the relativistic domain, while also providing critical early insights into the quantum world.
# *   **Bohr** delved into the **probabilistic, inherently uncertain quantum realm** of atoms and subatomic particles. He showed that at the smallest scales, reality behaves in ways that defy classical intuition, emphasizing wave-particle duality and the role of observation, defining the rules for modern quantum mechanics.
#
# Together, their work paints a picture of a universe far more complex and fascinating than could have been imagined by any one individual, constantly challenging our intuitions and pushing the boundaries of human knowledge. Each built upon the legacies of their predecessors, correcting, refining, and expanding our scientific world view in their own unique and profound ways.

# %%
for i in response.candidates[0].content.parts:
  print(i.text)
  print("*"*100)
# Out:
# **The Photosynthesis Puzzle: An Analogy-Driven Solution**
#
# Alright, let's break down this request for an explanation of photosynthesis using an analogy. My first step is to distill the core of the concept: reactants (water and carbon dioxide), energy source (sunlight), products (glucose and oxygen), and the two critical stages happening within the chloroplasts.  I need a relatable analogy that clearly maps these elements.
#
# My mind immediately begins to generate options: factory, restaurant, bakery, solar panel... but I settle on the bakery/kitchen because the final "product" of photosynthesis is food, which aligns perfectly with baking. The whole plant becomes the bakery itself, and the chloroplast is the kitchen. Sunlight is like electricity or the oven's heat, providing the necessary energy.  Water and carbon dioxide are the key ingredients like flour and sugar. The sweet baked good? That’s our glucose.  Oxygen then becomes a "byproduct," akin to steam or packaging waste.
#
# Now, the two-stage process is key.  I start to think of this kitchen in two distinct areas: the "prep station," and the "baking oven." The "prep station" is where sunlight and water do their initial work.  Water gets "broken down" like mixing ingredients, producing oxygen and, importantly, energy "helpers" – those essential ATP and NADPH – like pre-measured ingredients or powered tools, ready for the "oven."
#
# Then, we transition to the "baking oven" (the Calvin Cycle). Here, carbon dioxide meets the "energy helpers" and creates the delicious glucose!  This is where the "baking" happens, the final assembly.  The beauty of this bakery analogy is that it captures the essence of both stages and how they work together to create our plant's "food."
#
# To ensure clarity, I’ll frame this as "The Plant's Sunny Bakery," clearly mapping each component to the bakery equivalent.  I must explicitly state that oxygen is a byproduct in this context, even though it's vital for our own survival.  I’ll also emphasize the "pre-measured ingredients" analogy for those energy carriers.  This will hopefully make for a very understandable and accurate analogy for anyone trying to grasp this core biological process.
#
# ****************************************************************************************************
# Imagine a plant is like a **sunny, self-sufficient bakery** that specializes in making its own delicious sugar-based food.
#
# Here's how the analogy breaks down:
#
# *   **The Plant = The Entire Bakery**
#     This bakery isn't selling goods; it's making them *for itself* to grow and thrive.
#
# *   **The Chloroplasts = The Kitchens within the Bakery**
#     Every plant cell has these tiny "kitchens" (chloroplasts), which are where all the food-making magic happens.
#
# *   **Sunlight = The Bakery's Free, Renewable Electricity/Oven Heat**
#     This is the energy source that powers everything. Without it, the bakery simply cannot operate. It's like turning on the lights, the mixers, and the oven.
#
# *   **Water (H₂O) = The Liquid Ingredient (like water or milk for dough)**
#     The plant sips water up through its roots, sending it to the kitchens. This is one of the essential raw materials.
#
# *   **Carbon Dioxide (CO₂) = The Dry Ingredient (like flour or sugar for dough)**
#     The plant "breathes in" carbon dioxide from the air through tiny pores (stomata) on its leaves, sending it to the kitchens. This is the other essential raw material.
#
# *   **Glucose (C₆H₁₂O₆) = The Delicious Baked Goods (like bread, cookies, or cakes)**
#     This is the main product of the bakery! It's the sugar the plant makes for itself. It uses this sugar for energy to grow, repair, and store for later.
#
# *   **Oxygen (O₂) = The "Leftover" Steam or Byproduct Gas**
#     When the plant "bakes" its sugar, oxygen is released as a byproduct, much like steam comes off a hot oven, or excess flour dust might be released during baking. The plant doesn't need this oxygen *from this process* (though it uses some for its own respiration, like we do), so it releases it into the air for us to breathe!
#
# ---
#
# **Breaking it down into the Two Main "Baking" Stages:**
#
# 1.  **The "Prep Station" (Light-Dependent Reactions):**
#     *   Think of this as the *initial stage* in the kitchen where the **sunlight (electricity)** powers up special machinery.
#     *   **Water (liquid ingredient)** is brought in and, using the sunlight's energy, it's "split apart."
#     *   This splitting releases **Oxygen (steam/byproduct)** into the air.
#     *   More importantly, this stage creates **"Charged Batteries" (ATP & NADPH)** – these aren't the final baked goods, but they are crucial energy packets and chemical helpers, like fully charged power tools and pre-measured, activated ingredients, ready for the next step.
#
# 2.  **The "Baking Oven" (Light-Independent Reactions / Calvin Cycle):**
#     *   Now, the **Carbon Dioxide (dry ingredient)** is brought to the "oven."
#     *   Using the energy from the **"Charged Batteries" (ATP & NADPH)** created in the prep station, the **CO₂** is "baked" and transformed.
#     *   Through a complex series of steps (the "baking recipe"), the carbon atoms from the CO₂ are rearranged and combined to form **Glucose (the finished baked goods)**.
#
# So, in essence, the plant's sunny bakery uses free solar power, water, and air to whip up its own food, and as a bonus, gives us the air we breathe!
# ****************************************************************************************************

# %%
from google import genai
from google.genai import types

prompt = (
    "Four employees — A, B, C, and D — were in the office when a system error occurred. "
    "A says: 'B did it.' B says: 'D did it.' C says: 'I didn’t do it.' D says: 'B is lying.' "
    "Only one person is telling the truth. Who caused the error?")


client = genai.Client()
response = client.models.generate_content(
  model="gemini-2.5-pro",
  contents=prompt,
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

print(response.text)
# Out:
# Let's break down the logic to find the culprit. We know only one statement is true. Let's test each possibility.
#
# **Scenario 1: A is telling the truth.**
# *   A's statement: "B did it." is TRUE. (So, B is the culprit).
# *   B's statement: "D did it." must be FALSE. (This is consistent, as B is the culprit).
# *   C's statement: "I didn’t do it." must be FALSE. (This means C **did** do it).
# *   *This is a contradiction. B and C can't both be the culprit. So, A is not the one telling the truth.*
#
# **Scenario 2: B is telling the truth.**
# *   B's statement: "D did it." is TRUE. (So, D is the culprit).
# *   A's statement: "B did it." must be FALSE. (This is consistent).
# *   C's statement: "I didn’t do it." must be FALSE. (This means C **did** do it).
# *   *This is a contradiction. D and C can't both be the culprit. So, B is not the one telling the truth.*
#
# **Scenario 3: C is telling the truth.**
# *   C's statement: "I didn’t do it." is TRUE. (So, C is innocent).
# *   A's statement: "B did it." must be FALSE. (So, B is innocent).
# *   B's statement: "D did it." must be FALSE. (So, D is innocent).
# *   D's statement: "B is lying." must be FALSE. (This means B is telling the **truth**).
# *   *This is a contradiction. We assumed only C is telling the truth, but this scenario makes B a truth-teller as well. So, C is not the one telling the truth.*
#
# **Scenario 4: D is telling the truth.**
# *   D's statement: "B is lying." is TRUE.
# *   This means B's statement ("D did it.") is FALSE. (So, D is innocent).
# *   Since D is the only truth-teller, the other statements must be false.
# *   A's statement: "B did it." is FALSE. (So, B is innocent).
# *   C's statement: "I didn’t do it." is FALSE. (This means **C did do it**).
#
# This scenario works perfectly. There are no contradictions. We have one truth-teller (D) and one culprit (C).
#
# Therefore, **C caused the error.**

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**Decoding the System Error: A Logic Puzzle**
#
# Alright, I've got a classic on my hands, a logic puzzle! The user wants me to figure out who's responsible for this system error, given a set of statements, and knowing only one person is telling the truth. Let's break it down: we have four suspects – A, B, C, and D – and four statements. My approach is to methodically test each possible scenario, assuming one person is the truth-teller at a time. This should be straightforward.
#
# First, I need to look at each statement and think what it really means:
#
# *   **A says, "B did it."**
# *   **B says, "D did it."**
# *   **C says, "I didn't do it."**
# *   **D says, "B is lying."**
#
# I'm setting up my analysis in four distinct scenarios, one for each potential truth-teller: Scenario 1 with A, Scenario 2 with B, Scenario 3 with C, and Scenario 4 with D. For each scenario, I will: (1) suppose the person is telling the truth, and (2) analyze whether this fits with the other statements.
#
# *   **Scenario 1: Assume A is telling the truth.** If A is true, then B is guilty. This would mean all other statements are false. But right away, this is a problem. If A is true, and B is the culprit, this means C's statement is false, and therefore, C did it. Contradiction: If A's statement is true, B did it. If C is false, C did it. This scenario doesn't work.
#
# *   **Scenario 2: Assume B is telling the truth.** If B's is telling the truth, then D did it. Again, we are looking for a singular culprit. If B is true, then A is false and C is false. This means C did it. Contradiction: B says D is guilty. C says they are not guilty. If C is telling a lie, C is guilty. Again, there are two guilty people. No! This scenario is impossible.
#
# *   **Scenario 3: Assume C is telling the truth.** If C is telling the truth, then C is innocent. This means A, B, and D are lying. But again, this is a problem. D's statement ("B is lying") would be false, which means B is telling the truth... which contradicts the fact that we've assumed only C is telling the truth. Also, if C is true, this means A and B are both lying, and C is innocent. This scenario fails.
#
# *   **Scenario 4: Assume D is telling the truth.** This is the last possibility. D's statement says "B is lying" is TRUE. This means B's statement "D did it" is FALSE, which means D is innocent. Now, if D is the only one telling the truth, then all other statements must be false. A is false means B didn't do it. B is false means D didn't do it. If C is false, this means C did it. This is consistent!
#
# Looking back, if only D is telling the truth, then only C is guilty. Everyone else is innocent. C's statement is false, meaning C did it. This scenario holds up! Therefore, I can confidently conclude that C caused the system error.
# """,
#             thought=True
#           ),
#           Part(
#             text="""Let's break down the logic to find the culprit. We know only one statement is true. Let's test each possibility.
#
# **Scenario 1: A is telling the truth.**
# *   A's statement: "B did it." is TRUE. (So, B is the culprit).
# *   B's statement: "D did it." must be FALSE. (This is consistent, as B is the culprit).
# *   C's statement: "I didn’t do it." must be FALSE. (This means C **did** do it).
# *   *This is a contradiction. B and C can't both be the culprit. So, A is not the one telling the truth.*
#
# **Scenario 2: B is telling the truth.**
# *   B's statement: "D did it." is TRUE. (So, D is the culprit).
# *   A's statement: "B did it." must be FALSE. (This is consistent).
# *   C's statement: "I didn’t do it." must be FALSE. (This means C **did** do it).
# *   *This is a contradiction. D and C can't both be the culprit. So, B is not the one telling the truth.*
#
# **Scenario 3: C is telling the truth.**
# *   C's statement: "I didn’t do it." is TRUE. (So, C is innocent).
# *   A's statement: "B did it." must be FALSE. (So, B is innocent).
# *   B's statement: "D did it." must be FALSE. (So, D is innocent).
# *   D's statement: "B is lying." must be FALSE. (This means B is telling the **truth**).
# *   *This is a contradiction. We assumed only C is telling the truth, but this scenario makes B a truth-teller as well. So, C is not the one telling the truth.*
#
# **Scenario 4: D is telling the truth.**
# *   D's statement: "B is lying." is TRUE.
# *   This means B's statement ("D did it.") is FALSE. (So, D is innocent).
# *   Since D is the only truth-teller, the other statements must be false.
# *   A's statement: "B did it." is FALSE. (So, B is innocent).
# *   C's statement: "I didn’t do it." is FALSE. (This means **C did do it**).
#
# This scenario works perfectly. There are no contradictions. We have one truth-teller (D) and one culprit (C).
#
# Therefore, **C caused the error.**"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-pro',
#   response_id='bSlPaf_GPJCS_uMPsZT_4A8',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=584,
#     prompt_token_count=71,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=71
#       ),
#     ],
#     thoughts_token_count=1689,
#     total_token_count=2344
#   )
# )

# %%
from google import genai
from google.genai import types

prompt = (
    "Four employees — A, B, C, and D — were in the office when a system error occurred. "
    "A says: 'B did it.' B says: 'D did it.' C says: 'I didn’t do it.' D says: 'B is lying.' "
    "Only one person is telling the truth. Who caused the error?")


client = genai.Client()
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=prompt,
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

print(response.text)
# Out:
# Let's analyze the statements:
#
# 1.  **A:** "B did it."
# 2.  **B:** "D did it."
# 3.  **C:** "I didn't do it."
# 4.  **D:** "B is lying."
#
# Notice statements B and D are direct contradictions:
# *   If B is telling the truth, then D did it, and D's statement ("B is lying") is false.
# *   If B is lying, then D did not do it, and D's statement ("B is lying") is true.
#
# This means that exactly one of B and D must be telling the truth.
#
# Since only one person in total is telling the truth, and we've identified that either B or D is the truth-teller, it follows that **A and C must be lying.**
#
# Let's deduce what happened based on A and C lying:
#
# *   **A says "B did it."** Since A is lying, **B did NOT do it.**
# *   **C says "I didn't do it."** Since C is lying, **C DID do it.**
#
# Now, let's check this scenario against all statements to ensure only one person is telling the truth:
#
# *   **If C did it:**
#     *   **A:** "B did it." (False - A is lying, consistent)
#     *   **B:** "D did it." (False - C did it, consistent)
#     *   **C:** "I didn't do it." (False - C did it, consistent)
#     *   **D:** "B is lying." (True - B said "D did it," but D didn't do it, so B is indeed lying. D is telling the truth, consistent)
#
# This scenario fits all the conditions: C caused the error, and only D is telling the truth.
#
# **Therefore, C caused the error.**

# %%
client = genai.Client()
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents=" From a point Q, the length of the tangent to a circle is 24 cm and the distance of Q from the centre is 25 cm. Find the radius of the circle, also find area of circle",
  config=types.GenerateContentConfig(
      system_instruction="you only  give answers to what is asked, give me exact answers no round off, give me final output using the value of pie as 3.14",
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
  )
)

print(response.text)
# Out:
# Radius of the circle = 7 cm
# Area of the circle = 153.86 cm$^2$

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**Solving for Radius and Area of a Circle**
#
# Okay, I've got this. The user wants the radius and area of a circle. I'm given the length of a tangent from a point outside the circle and the distance of that point from the circle's center. I can definitely work with this.
#
# First, I'll find the radius. I need to visualize a right triangle. The radius drawn to the point of tangency is perpendicular to the tangent line, creating a right angle.  Let's call the circle's center O, the point of tangency T, and the external point Q.  OQ will be the hypotenuse, and TQ is one leg. I know OQ is 25 cm and TQ is 24 cm.  Using the Pythagorean theorem, $OT^2 + TQ^2 = OQ^2$, I can solve for the radius, OT (which I'll call *r*). So,  $r^2 + 24^2 = 25^2$. This simplifies to $r^2 + 576 = 625$.  Therefore, $r^2 = 49$, and $r = 7$ cm.
#
# Now, I'll calculate the area. The formula is $A = \pi r^2$.  The user wants me to use $\pi = 3.14$. Plugging in my calculated radius, $A = 3.14 \times 7^2 = 3.14 \times 49$. Doing the multiplication, I get 153.86 cm$^2$.
#
# Let's check: Radius is indeed 7 cm and the area is 153.86 cm$^2$, using the provided value for pi. All good!
# """,
#             thought=True
#           ),
#           Part(
#             text="""Radius of the circle = 7 cm
# Area of the circle = 153.86 cm$^2$"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='Qi1PacOWDNzg_uMP7ev2oA8',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=25,
#     prompt_token_count=79,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=79
#       ),
#     ],
#     thoughts_token_count=519,
#     total_token_count=623
#   )
# )

# %%
# you can control the thinking tokens that model use when generating  a response.
# higher token count is for more detailed reasoning, which can be beneficial for tackling more complex tasks
# If latency is more important, use a lower budget or infact you can turn of the thinking if required.
# this all can be done using the thinking_config parameter under the object of the class generate content config


client = genai.Client()
response = client.models.generate_content(
  model="gemini-2.5-flash",
  contents="Compare the Scientific Contribution of Issac Newton, Albert Einsteinand Neil Bohr.Highlight How each one shaped the physics",
  # contents="Hello",
  config=types.GenerateContentConfig(
    thinking_config=types.ThinkingConfig(
      include_thoughts=True,
      thinkingBudget= 500
    )
  )
)

print(response.text)
# Out:
# Isaac Newton, Albert Einstein, and Niels Bohr represent three distinct epochs and paradigm shifts in the history of physics. Each, in their own right, fundamentally altered our understanding of the universe, from the macroscopic to the quantum realm.
#
# Let's compare their scientific contributions and highlight how each shaped physics:
#
# ---
#
# ## 1. Sir Isaac Newton (1643 – 1727)
#
# **Era:** Classical Physics, The Scientific Revolution
#
# **Key Contributions:**
#
# 1.  **Laws of Motion:** Newton formulated three fundamental laws that describe the relationship between a body and the forces acting upon it, and its motion in response to those forces. These are the bedrock of classical mechanics.
#     *   **First Law (Inertia):** An object at rest stays at rest and an object in motion stays in motion with the same speed and in the same direction unless acted upon by an unbalanced force.
#     *   **Second Law (F=ma):** The acceleration of an object as produced by a net force is directly proportional to the magnitude of the net force, in the same direction as the net force, and inversely proportional to the mass of the object.
#     *   **Third Law (Action-Reaction):** For every action, there is an equal and opposite reaction.
# 2.  **Law of Universal Gravitation:** He described gravity as a universal force of attraction between any two objects with mass, proportional to the product of their masses and inversely proportional to the square of the distance between their centers ($F = G \frac{m_1 m_2}{r^2}$). This law unified terrestrial and celestial mechanics, explaining phenomena from falling apples to planetary orbits.
# 3.  **Calculus:** Co-invented (with Leibniz) differential and integral calculus, providing the mathematical tools necessary to describe continuous change and motion, which were essential for his physical theories.
# 4.  **Optics:** Conducted extensive experiments with light, demonstrating that white light is composed of a spectrum of colors and proposing a corpuscular (particle) theory of light. He also invented the reflecting telescope.
# 5.  **Principia Mathematica:** His magnum opus, published in 1687, laid out his laws of motion and gravitation with unprecedented mathematical rigor, establishing the scientific method and predictive power of mathematical physics.
#
# **How he Shaped Physics:**
#
# *   **Unified the Cosmos:** Newton single-handedly reconciled the physics of the heavens with the physics of the Earth, showing that the same laws governed both celestial bodies and everyday objects. This was a monumental intellectual achievement.
# *   **Foundation of Classical Physics:** His laws of motion and gravitation formed the bedrock of classical physics for over two centuries, allowing for precise predictions of the motion of objects, planets, and even the tides.
# *   **Deterministic Universe:** Newtonian physics fostered a worldview where the universe was seen as a giant, predictable clockwork mechanism. Given the initial conditions, the future state of the universe could, in principle, be calculated.
# *   **Mathematical Rigor:** He established the paradigm of using sophisticated mathematics (like calculus) to formulate physical laws and derive testable predictions, setting a new standard for scientific inquiry.
# *   **Empirical and Theoretical Synthesis:** Newton was a master of both meticulous observation and bold theoretical construction, demonstrating the power of integrating both approaches in science.
#
# ---
#
# ## 2. Albert Einstein (1879 – 1955)
#
# **Era:** Modern Physics, Relativity and the Early Quantum Era
#
# **Key Contributions:**
#
# 1.  **Special Theory of Relativity (1905):** Based on two postulates:
#     *   The laws of physics are the same for all observers in uniform motion relative to one another (principle of relativity).
#     *   The speed of light in a vacuum is the same for all inertial observers, regardless of the motion of the light source.
#     This led to revolutionary concepts like:
#     *   **Time Dilation:** Time passes differently for observers in relative motion.
#     *   **Length Contraction:** Objects appear shorter in their direction of motion.
#     *   **Mass-Energy Equivalence ($E=mc^2$):** Mass and energy are interchangeable, demonstrating that a small amount of mass can be converted into a vast amount of energy.
#     *   **No Absolute Simultaneity:** Events simultaneous for one observer may not be for another.
# 2.  **General Theory of Relativity (1915):** An extension of special relativity, incorporating gravity.
#     *   **Gravity as Spacetime Curvature:** Instead of a force, Einstein described gravity as a manifestation of the curvature of spacetime caused by mass and energy. Objects follow the curves in spacetime, not being pulled by a force.
#     *   **Equivalence Principle:** The effects of gravity are indistinguishable from the effects of acceleration.
#     *   Predicted phenomena like gravitational lensing, black holes, and gravitational waves (later confirmed).
# 3.  **Photoelectric Effect (1905):** Explained that light consists of discrete packets of energy called "quanta" or photons, which are absorbed or emitted in whole units. This work earned him the Nobel Prize in Physics in 1921 and was a crucial early contribution to quantum theory, despite his later discomfort with its probabilistic nature.
# 4.  **Brownian Motion (1905):** Provided a theoretical explanation for the seemingly random movement of particles suspended in a fluid, confirming the existence of atoms and molecules and providing a method to estimate their size.
# 5.  **Quantum Theory of Heat Capacity:** Contributed to understanding the specific heat of solids at low temperatures using quantum principles.
#
# **How he Shaped Physics:**
#
# *   **Overthrew Newtonian Absolutes:** Einstein shattered Newton's concepts of absolute space and absolute time, replacing them with a dynamic, interconnected spacetime that is relative to the observer's motion.
# *   **New Understanding of Gravity:** Transformed gravity from a mysterious force into a geometric property of spacetime itself, leading to modern cosmology and the study of extreme gravitational phenomena.
# *   **Opened the Quantum Door (Reluctantly):** While he later became a critic of quantum mechanics, his work on the photoelectric effect was a foundational pillar, establishing the quantum nature of light and opening the door to understanding the subatomic world.
# *   **Cosmological Impact:** General Relativity provided the framework for understanding the large-scale structure and evolution of the universe, leading to theories like the Big Bang.
# *   **Energy and Matter Equivalence:** His $E=mc^2$ equation profoundly changed our understanding of the relationship between mass and energy, with vast implications for nuclear physics and energy generation.
#
# ---
#
# ## 3. Niels Bohr (1885 – 1962)
#
# **Era:** Quantum Physics, The Atomic Age
#
# **Key Contributions:**
#
# 1.  **Bohr Model of the Atom (1913):** Proposed a revolutionary model for the hydrogen atom (and later extended to other atoms) that applied quantum mechanics to the structure of the atom. Key postulates included:
#     *   Electrons orbit the nucleus in specific, stable "stationary states" or energy levels without radiating energy.
#     *   Electrons can only jump between these discrete energy levels by absorbing or emitting photons of specific energies, equal to the difference between the energy levels ($E_f - E_i = hf$).
#     *   The angular momentum of an electron in an orbit is quantized ($L = n \frac{h}{2\pi}$).
#     This model successfully explained the discrete spectral lines of hydrogen.
# 2.  **The Copenhagen Interpretation of Quantum Mechanics:** Developed (with Werner Heisenberg and others) the most widely accepted interpretation of quantum mechanics. Its key tenets include:
#     *   **Wave-Particle Duality:** Quantum entities exhibit characteristics of both waves and particles.
#     *   **Probability:** The outcomes of quantum events are inherently probabilistic, not deterministic.
#     *   **Uncertainty Principle:** It is impossible to simultaneously know with perfect precision certain pairs of properties of a particle (e.g., position and momentum).
#     *   **Role of the Observer:** The act of measurement "collapses" the wave function, forcing a quantum system into a definite state.
# 3.  **Complementarity Principle:** Proposed that certain properties of quantum objects, such as wave and particle behavior, are complementary; they cannot be observed simultaneously but are both necessary for a complete description of the phenomenon.
# 4.  **Nuclear Fission Theory:** Made significant contributions to understanding nuclear fission, particularly the liquid drop model of the nucleus.
#
# **How he Shaped Physics:**
#
# *   **Bridged Classical and Quantum:** Bohr's model was a crucial stepping stone, incorporating quantum ideas into the structure of the atom while still retaining some classical concepts (like orbits). It provided the first successful quantum explanation of atomic structure and spectra.
# *   **Atomic Structure and Chemistry:** His model laid the foundation for understanding atomic structure, explaining the chemical properties of elements and the periodic table.
# *   **Philosophical Implications of Quantum Mechanics:** Bohr was a profound thinker about the philosophical implications of quantum theory. The Copenhagen Interpretation profoundly changed our understanding of reality, causality, and the role of the observer in physics.
# *   **Shift to Probabilistic Universe:** Unlike Newton's deterministic universe or Einstein's geometric one, Bohr's quantum world introduced inherent uncertainty and probability as fundamental aspects of reality at the smallest scales, which many physicists (including Einstein) struggled to accept.
# *   **Modern Quantum Theory:** While the Bohr model was eventually superseded by more sophisticated quantum mechanics (like Schrödinger's equation), it was the essential conceptual leap that paved the way for the full development of quantum field theory and our understanding of particle physics.
#
# ---
#
# ## Conclusion: An Evolving Tapestry of Reality
#
# These three titans of physics represent a continuous evolution of our understanding of the universe:
#
# *   **Newton** gave us a **deterministic, mechanistic universe** governed by universal forces and mathematical laws, unifying the terrestrial and celestial realms. He provided the framework for classical physics that was incredibly successful for centuries.
# *   **Einstein** revolutionized our understanding of space, time, gravity, and the very fabric of the cosmos, showing a **relative, interconnected spacetime** where gravity is geometry. He introduced concepts that pushed Newton's classical view to its limits and into the relativistic domain, while also providing critical early insights into the quantum world.
# *   **Bohr** delved into the **probabilistic, inherently uncertain quantum realm** of atoms and subatomic particles. He showed that at the smallest scales, reality behaves in ways that defy classical intuition, emphasizing wave-particle duality and the role of observation, defining the rules for modern quantum mechanics.
#
# Together, their work paints a picture of a universe far more complex and fascinating than could have been imagined by any one individual, constantly challenging our intuitions and pushing the boundaries of human knowledge. Each built upon the legacies of their predecessors, correcting, refining, and expanding our scientific world view in their own unique and profound ways.

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**Delving into the Titans of Physics**
#
# Okay, here's how I'd approach this. The core is a comparison of Newton, Einstein, and Bohr, looking at how they *shaped* physics, not just what they did. So, it's about the impact, the paradigm shifts they brought.
#
# First, a quick brainstorm. For *Newton*, it's classical mechanics – laws of motion, universal gravitation. He gave us calculus too, and optics. His big deal was unifying terrestrial and celestial physics and a deterministic universe. Also, that incredible mathematical rigor and predictive power.
#
# Then, *Einstein*. Relativity, special and general. The photoelectric effect, which was a real quantum leap, and Brownian motion, proving the existence of atoms. E=mc², that’s *massive*. He gave us space-time curvature – gravity as geometry. A relativistic view, no absolute simultaneity. Basically, the shift from classical to modern physics, the first half, I'd say.
#
# And finally, *Bohr*. His atomic model, that's key. Quantization of energy levels. The Copenhagen Interpretation, the complementarity principle, setting the foundation for quantum theory as it applied to atoms. Also, philosophical implications of quantum mechanics - probability, the role of the observer, getting at the smallest scales of matter.
#
# The structure? Introduction, quick overview. Then, individual sections for each scientist, Contributions, Key Ideas, Impact – how each *shaped* physics. Then, a comparative analysis – maybe a table or a paragraph, highlighting the differences and the evolution. Finally, a conclusion, summarizing their combined impact.
#
# Let's start with Newton. His contributions are the Laws of Motion, Universal Gravitation, Calculus, and Optics. His key ideas in mechanics? Inertia, F=ma, action-reaction. Right, so Newton gave us the bedrock…
# """,
#             thought=True
#           ),
#           Part(
#             text="""Isaac Newton, Albert Einstein, and Niels Bohr represent three distinct epochs and paradigm shifts in the history of physics. Each, in their own right, fundamentally altered our understanding of the universe, from the macroscopic to the quantum realm.
#
# Let's compare their scientific contributions and highlight how each shaped physics:
#
# ---
#
# ## 1. Sir Isaac Newton (1643 – 1727)
#
# **Era:** Classical Physics, The Scientific Revolution
#
# **Key Contributions:**
#
# 1.  **Laws of Motion:** Newton formulated three fundamental laws that describe the relationship between a body and the forces acting upon it, and its motion in response to those forces. These are the bedrock of classical mechanics.
#     *   **First Law (Inertia):** An object at rest stays at rest and an object in motion stays in motion with the same speed and in the same direction unless acted upon by an unbalanced force.
#     *   **Second Law (F=ma):** The acceleration of an object as produced by a net force is directly proportional to the magnitude of the net force, in the same direction as the net force, and inversely proportional to the mass of the object.
#     *   **Third Law (Action-Reaction):** For every action, there is an equal and opposite reaction.
# 2.  **Law of Universal Gravitation:** He described gravity as a universal force of attraction between any two objects with mass, proportional to the product of their masses and inversely proportional to the square of the distance between their centers ($F = G \frac{m_1 m_2}{r^2}$). This law unified terrestrial and celestial mechanics, explaining phenomena from falling apples to planetary orbits.
# 3.  **Calculus:** Co-invented (with Leibniz) differential and integral calculus, providing the mathematical tools necessary to describe continuous change and motion, which were essential for his physical theories.
# 4.  **Optics:** Conducted extensive experiments with light, demonstrating that white light is composed of a spectrum of colors and proposing a corpuscular (particle) theory of light. He also invented the reflecting telescope.
# 5.  **Principia Mathematica:** His magnum opus, published in 1687, laid out his laws of motion and gravitation with unprecedented mathematical rigor, establishing the scientific method and predictive power of mathematical physics.
#
# **How he Shaped Physics:**
#
# *   **Unified the Cosmos:** Newton single-handedly reconciled the physics of the heavens with the physics of the Earth, showing that the same laws governed both celestial bodies and everyday objects. This was a monumental intellectual achievement.
# *   **Foundation of Classical Physics:** His laws of motion and gravitation formed the bedrock of classical physics for over two centuries, allowing for precise predictions of the motion of objects, planets, and even the tides.
# *   **Deterministic Universe:** Newtonian physics fostered a worldview where the universe was seen as a giant, predictable clockwork mechanism. Given the initial conditions, the future state of the universe could, in principle, be calculated.
# *   **Mathematical Rigor:** He established the paradigm of using sophisticated mathematics (like calculus) to formulate physical laws and derive testable predictions, setting a new standard for scientific inquiry.
# *   **Empirical and Theoretical Synthesis:** Newton was a master of both meticulous observation and bold theoretical construction, demonstrating the power of integrating both approaches in science.
#
# ---
#
# ## 2. Albert Einstein (1879 – 1955)
#
# **Era:** Modern Physics, Relativity and the Early Quantum Era
#
# **Key Contributions:**
#
# 1.  **Special Theory of Relativity (1905):** Based on two postulates:
#     *   The laws of physics are the same for all observers in uniform motion relative to one another (principle of relativity).
#     *   The speed of light in a vacuum is the same for all inertial observers, regardless of the motion of the light source.
#     This led to revolutionary concepts like:
#     *   **Time Dilation:** Time passes differently for observers in relative motion.
#     *   **Length Contraction:** Objects appear shorter in their direction of motion.
#     *   **Mass-Energy Equivalence ($E=mc^2$):** Mass and energy are interchangeable, demonstrating that a small amount of mass can be converted into a vast amount of energy.
#     *   **No Absolute Simultaneity:** Events simultaneous for one observer may not be for another.
# 2.  **General Theory of Relativity (1915):** An extension of special relativity, incorporating gravity.
#     *   **Gravity as Spacetime Curvature:** Instead of a force, Einstein described gravity as a manifestation of the curvature of spacetime caused by mass and energy. Objects follow the curves in spacetime, not being pulled by a force.
#     *   **Equivalence Principle:** The effects of gravity are indistinguishable from the effects of acceleration.
#     *   Predicted phenomena like gravitational lensing, black holes, and gravitational waves (later confirmed).
# 3.  **Photoelectric Effect (1905):** Explained that light consists of discrete packets of energy called "quanta" or photons, which are absorbed or emitted in whole units. This work earned him the Nobel Prize in Physics in 1921 and was a crucial early contribution to quantum theory, despite his later discomfort with its probabilistic nature.
# 4.  **Brownian Motion (1905):** Provided a theoretical explanation for the seemingly random movement of particles suspended in a fluid, confirming the existence of atoms and molecules and providing a method to estimate their size.
# 5.  **Quantum Theory of Heat Capacity:** Contributed to understanding the specific heat of solids at low temperatures using quantum principles.
#
# **How he Shaped Physics:**
#
# *   **Overthrew Newtonian Absolutes:** Einstein shattered Newton's concepts of absolute space and absolute time, replacing them with a dynamic, interconnected spacetime that is relative to the observer's motion.
# *   **New Understanding of Gravity:** Transformed gravity from a mysterious force into a geometric property of spacetime itself, leading to modern cosmology and the study of extreme gravitational phenomena.
# *   **Opened the Quantum Door (Reluctantly):** While he later became a critic of quantum mechanics, his work on the photoelectric effect was a foundational pillar, establishing the quantum nature of light and opening the door to understanding the subatomic world.
# *   **Cosmological Impact:** General Relativity provided the framework for understanding the large-scale structure and evolution of the universe, leading to theories like the Big Bang.
# *   **Energy and Matter Equivalence:** His $E=mc^2$ equation profoundly changed our understanding of the relationship between mass and energy, with vast implications for nuclear physics and energy generation.
#
# ---
#
# ## 3. Niels Bohr (1885 – 1962)
#
# **Era:** Quantum Physics, The Atomic Age
#
# **Key Contributions:**
#
# 1.  **Bohr Model of the Atom (1913):** Proposed a revolutionary model for the hydrogen atom (and later extended to other atoms) that applied quantum mechanics to the structure of the atom. Key postulates included:
#     *   Electrons orbit the nucleus in specific, stable "stationary states" or energy levels without radiating energy.
#     *   Electrons can only jump between these discrete energy levels by absorbing or emitting photons of specific energies, equal to the difference between the energy levels ($E_f - E_i = hf$).
#     *   The angular momentum of an electron in an orbit is quantized ($L = n \frac{h}{2\pi}$).
#     This model successfully explained the discrete spectral lines of hydrogen.
# 2.  **The Copenhagen Interpretation of Quantum Mechanics:** Developed (with Werner Heisenberg and others) the most widely accepted interpretation of quantum mechanics. Its key tenets include:
#     *   **Wave-Particle Duality:** Quantum entities exhibit characteristics of both waves and particles.
#     *   **Probability:** The outcomes of quantum events are inherently probabilistic, not deterministic.
#     *   **Uncertainty Principle:** It is impossible to simultaneously know with perfect precision certain pairs of properties of a particle (e.g., position and momentum).
#     *   **Role of the Observer:** The act of measurement "collapses" the wave function, forcing a quantum system into a definite state.
# 3.  **Complementarity Principle:** Proposed that certain properties of quantum objects, such as wave and particle behavior, are complementary; they cannot be observed simultaneously but are both necessary for a complete description of the phenomenon.
# 4.  **Nuclear Fission Theory:** Made significant contributions to understanding nuclear fission, particularly the liquid drop model of the nucleus.
#
# **How he Shaped Physics:**
#
# *   **Bridged Classical and Quantum:** Bohr's model was a crucial stepping stone, incorporating quantum ideas into the structure of the atom while still retaining some classical concepts (like orbits). It provided the first successful quantum explanation of atomic structure and spectra.
# *   **Atomic Structure and Chemistry:** His model laid the foundation for understanding atomic structure, explaining the chemical properties of elements and the periodic table.
# *   **Philosophical Implications of Quantum Mechanics:** Bohr was a profound thinker about the philosophical implications of quantum theory. The Copenhagen Interpretation profoundly changed our understanding of reality, causality, and the role of the observer in physics.
# *   **Shift to Probabilistic Universe:** Unlike Newton's deterministic universe or Einstein's geometric one, Bohr's quantum world introduced inherent uncertainty and probability as fundamental aspects of reality at the smallest scales, which many physicists (including Einstein) struggled to accept.
# *   **Modern Quantum Theory:** While the Bohr model was eventually superseded by more sophisticated quantum mechanics (like Schrödinger's equation), it was the essential conceptual leap that paved the way for the full development of quantum field theory and our understanding of particle physics.
#
# ---
#
# ## Conclusion: An Evolving Tapestry of Reality
#
# These three titans of physics represent a continuous evolution of our understanding of the universe:
#
# *   **Newton** gave us a **deterministic, mechanistic universe** governed by universal forces and mathematical laws, unifying the terrestrial and celestial realms. He provided the framework for classical physics that was incredibly successful for centuries.
# *   **Einstein** revolutionized our understanding of space, time, gravity, and the very fabric of the cosmos, showing a **relative, interconnected spacetime** where gravity is geometry. He introduced concepts that pushed Newton's classical view to its limits and into the relativistic domain, while also providing critical early insights into the quantum world.
# *   **Bohr** delved into the **probabilistic, inherently uncertain quantum realm** of atoms and subatomic particles. He showed that at the smallest scales, reality behaves in ways that defy classical intuition, emphasizing wave-particle duality and the role of observation, defining the rules for modern quantum mechanics.
#
# Together, their work paints a picture of a universe far more complex and fascinating than could have been imagined by any one individual, constantly challenging our intuitions and pushing the boundaries of human knowledge. Each built upon the legacies of their predecessors, correcting, refining, and expanding our scientific world view in their own unique and profound ways."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='djRPaZnLLvzj_uMPx4Cq-A4',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=2306,
#     prompt_token_count=23,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=23
#       ),
#     ],
#     thoughts_token_count=467,
#     total_token_count=2796
#   )
# )

# %%
prompt= """

SOLVE THE PROBLEM FOR ME
Sixty-four players seeded from seed 1 to seed 64 participated in a knock-out tennis tournament. Seed 1 is the highest seed and seed 64 is the lowest seed. The tournament would be played in six rounds i.e., first round, second round, third round, quarterfinals, semi finals and final. In the first round, the player with the highest seed (i.e., 1) would play with the player with the lowest seed (i.e., 64) which is designated Match No.1.
Similarly, the player with the second highest seed (i.e., 2) would play with the player with the second lowest seed (i.e., 63), which is designated Match No.2 and so on. In the second round, the winner of the Match No.1 of the first round would play with the winner of the Match No.32 of the first round and this match is designated Match No.1 of the second round.
Similarly, the winner of the Match No.2 of the first round would play with the winner of the Match No.31 of the first round and this match is designated Match No.2 of the second round and so on. In the similar pattern the subsequent rounds will be played.

Q1. If the player seeded 43 won the tournament, then which of the following players cannot be the runner-up?

Player seeded 44
Player seeded 45
Player seeded 46
Player seeded 36
Q2. Who could be the lowest seeded player facing the player seeded 12 in the finals?

57
59
62
63
"""
response = client.models.generate_content(
    model = "gemini-2.5-pro",
    contents=prompt,
    config=types.GenerateContentConfig(
    system_instruction="you only give answers to what is asked , you dont give any other thing in your output SOlve first 2 questions",
    thinking_config=types.ThinkingConfig(
      include_thoughts=True
    )
)
)
print(response.text)
# Out:
# **Q1. If the player seeded 43 won the tournament, then which of the following players cannot be the runner-up?**
#
# Player seeded 46
#
# **Q2. Who could be the lowest seeded player facing the player seeded 12 in the finals?**
#
# 63

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""**Tournament Analysis & Answer Generation:**
#
# Alright, here's what I've got: a 64-player knockout tennis tournament, seeded from 1 to 64.  I need to figure out who can meet whom and in which round, especially to answer a couple of questions.  I've laid out the bracket structure – six rounds, starting with 32 matches in the first round.  The pairing is specific: seed *i* plays seed (65 - *i*) in the first round. The subsequent rounds follow a similar pattern, pairing winners of previous matches.
#
# I've divided the bracket into two "halves," which will be key for the questions.  The first question is tricky, it asks who *can't* be the runner-up if a certain seed won. I've figured out that the runner-up has to be from a different half than the winner. Checking the provided options reveals that, based on my seed breakdown, seed 46 is from the same half as the winning seed 43 and therefore cannot be the runner-up.
#
# For the second question, the aim is to find the lowest-seeded player who *could* face the seed 12 player in the finals. Again, I've split the bracket in halves. I know the finalist opponent must be from the opposite half. After analyzing which options are on the opposite side of the bracket I can see that 63 is the lowest-seeded player in the tournament who could face seed 12 in the final.
#
# So, I'm confident with these answers.
# Q1 Answer is Player seeded 46.
# Q2 Answer is 63.
# """,
#             thought=True
#           ),
#           Part(
#             text="""**Q1. If the player seeded 43 won the tournament, then which of the following players cannot be the runner-up?**
#
# Player seeded 46
#
# **Q2. Who could be the lowest seeded player facing the player seeded 12 in the finals?**
#
# 63"""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-pro',
#   response_id='lC1Pabq2C4Tg_uMP96HM2Qw',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=62,
#     prompt_token_count=390,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=390
#       ),
#     ],
#     thoughts_token_count=8827,
#     total_token_count=9279
#   )
# )

# %%
for i in response.candidates[0].content.parts:
  print(i.text)
  print("*"*100)
# Out:
# **Tournament Analysis & Answer Generation:**
#
# Alright, here's what I've got: a 64-player knockout tennis tournament, seeded from 1 to 64.  I need to figure out who can meet whom and in which round, especially to answer a couple of questions.  I've laid out the bracket structure – six rounds, starting with 32 matches in the first round.  The pairing is specific: seed *i* plays seed (65 - *i*) in the first round. The subsequent rounds follow a similar pattern, pairing winners of previous matches.
#
# I've divided the bracket into two "halves," which will be key for the questions.  The first question is tricky, it asks who *can't* be the runner-up if a certain seed won. I've figured out that the runner-up has to be from a different half than the winner. Checking the provided options reveals that, based on my seed breakdown, seed 46 is from the same half as the winning seed 43 and therefore cannot be the runner-up.
#
# For the second question, the aim is to find the lowest-seeded player who *could* face the seed 12 player in the finals. Again, I've split the bracket in halves. I know the finalist opponent must be from the opposite half. After analyzing which options are on the opposite side of the bracket I can see that 63 is the lowest-seeded player in the tournament who could face seed 12 in the final.
#
# So, I'm confident with these answers.
# Q1 Answer is Player seeded 46.
# Q2 Answer is 63.
#
# ****************************************************************************************************
# **Q1. If the player seeded 43 won the tournament, then which of the following players cannot be the runner-up?**
#
# Player seeded 46
#
# **Q2. Who could be the lowest seeded player facing the player seeded 12 in the finals?**
#
# 63
# ****************************************************************************************************

# %% [markdown]
# ## STRUCTURED OUTPUT

# %%
# Structured output refers to the ability to get information from the Gemini model in a well-organized, predictable format — usually as JSON,
#  CSV, or a table — instead of just free-form text (unstructured output like paragraphs).

# eg:-
# unstructured :- "Ajay Sati has 4 years of experience in data analytics. He worked at Infosys and specializes in Python, SQL, and Power BI."
# Structured :-
#     {
#   "name": "Ajay Sati",
#   "experience": "4 years",
#   "previous_company": "Infosys",
#   "skills": ["Python", "SQL", "Power BI"]
# }


# BENEFITS
#   Store in databases
#   Feed into automated pipelines
#   Analyze with BI tools or ML models
#   Use in system-to-system communication

# %%
#  Gemini can generate either JSON or enum values as structured output.



# lets start with json first
# JSON :- JSON stands for JavaScript Object Notation.
      #It is a lightweight, human-readable format used to store and exchange structured data between systems (especially between servers and
      # web applications).
      # JSON is made of key-value pairs.
      # {
      #   "key1": "value1",
      #   "key2": 123,
      #   "key3": true,
      #   "key4": [1, 2, 3],
      #   "key5": { "nestedKey": "nestedValue" }
      # }

# %%
# GENERATING JSON.

# WE NEED TO FIRST CONFIGURE THE SCHEMA ON THE MODEL.
# "Configure a schema on the model" means you tell the model in advance exactly what kind of structured response (e.g., JSON format) you want.
#  You define this using a predefined schema  which guides the model to fill out the correct fields in the  response.

# %%
from google import genai
from pydantic import BaseModel # IMPORTING PYDANTIC BASEMODEL CLASS..


class Programming_language(BaseModel):
  language_name: str
  Year_created: int
  creator: str
  Use_cases:list[str]


prompt = "List some popular programming languages, and for each, include its year of creation, the creator's name, and two common use cases."


response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents=prompt,
    config={
        "response_mime_type":"application/json",
        "response_schema":list[Programming_language]
    }

)

# %%
print(response.text)
# Out:
# [{"language_name":"Python","Year_created":1991,"creator":"Guido van Rossum","Use_cases":["Web Development","Data Science","Machine Learning"]},{"language_name":"JavaScript","Year_created":1995,"creator":"Brendan Eich","Use_cases":["Web Development (Frontend)","Backend Development (Node.js)","Mobile Applications"]},{"language_name":"Java","Year_created":1995,"creator":"James Gosling","Use_cases":["Enterprise Applications","Android Mobile Apps","Backend Systems"]},{"language_name":"C++","Year_created":1985,"creator":"Bjarne Stroustrup","Use_cases":["Game Development","System Programming","High-Performance Computing"]}]

# %%
# dataframe conversion
# we need to parse this output  into a list  of dict first
import pandas as pd
pd.DataFrame([i.model_dump() for i in response.parsed])
# Out:
#   language_name  Year_created            creator  \
# 0        Python          1991   Guido van Rossum
# 1    JavaScript          1995       Brendan Eich
# 2          Java          1995      James Gosling
# 3           C++          1985  Bjarne Stroustrup
#
#                                            Use_cases
# 0  [Web Development, Data Science, Machine Learning]
# 1  [Web Development (Frontend), Backend Developme...
# 2  [Enterprise Applications, Android Mobile Apps,...
# 3  [Game Development, System Programming, High-Pe...

# %%
# response.parse #
# convert them into dict.
# list ----- dataframe

# %%
from PIL import Image
from google import genai
from pydantic import BaseModel

class Citizen(BaseModel):
  name:str
  age:str
  gender:str
  address:str
  emp_id: str
  monthly_income:str
  income_currency:str

client = genai.Client()

image = Image.open("/content/Blue and White Modern Technology Article Page A4 Document.png")




response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents=[image, "From the given text, extract all the information that is available  as per the given  json structure."],
    config={
        "response_mime_type":"application/json",
        "response_schema":list[Citizen]
    }

)

# %%
print(response.text)
# Out:
# [
#   {
#     "name": "Alpha",
#     "age": "28",
#     "gender": "Male",
#     "address": "Dubai",
#     "emp_id": "-12345678",
#     "monthly_income": "1.2cr",
#     "income_currency": "USD"
#   },
#   {
#     "name": "Priya",
#     "age": "32",
#     "gender": "Female",
#     "address": "Mumbai",
#     "emp_id": "E-54321",
#     "monthly_income": "15 Lakhs",
#     "income_currency": "INR"
#   },
#   {
#     "name": "David",
#     "age": "45",
#     "gender": "Male",
#     "address": "London",
#     "emp_id": "LON-8899",
#     "monthly_income": "9,000",
#     "income_currency": "GBP"
#   },
#   {
#     "name": "Fatima",
#     "age": "29",
#     "gender": "Female",
#     "address": "Abu Dhabi",
#     "emp_id": "AD-765B",
#     "monthly_income": "40,000",
#     "income_currency": "AED"
#   },
#   {
#     "name": "Kenji",
#     "age": "38",
#     "gender": "Male",
#     "address": "Tokyo",
#     "emp_id": "TKY-1020",
#     "monthly_income": "1.5 million",
#     "income_currency": "JPY"
#   },
#   {
#     "name": "Chloe",
#     "age": "25",
#     "gender": "Female",
#     "address": "Sydney",
#     "emp_id": "SYD-6543",
#     "monthly_income": "12,000",
#     "income_currency": "AUD"
#   },
#   {
#     "name": "Raj",
#     "age": "52",
#     "gender": "Male",
#     "address": "Bangalore",
#     "emp_id": "BLR-007",
#     "monthly_income": "2.5 cr",
#     "income_currency": "INR"
#   },
#   {
#     "name": "Sofia",
#     "age": "35",
#     "gender": "Female",
#     "address": "New York",
#     "emp_id": "NYC-2024A",
#     "monthly_income": "25,000",
#     "income_currency": "USD"
#   },
#   {
#     "name": "Omar",
#     "age": "41",
#     "gender": "Male",
#     "address": "Riyadh",
#     "emp_id": "SA-9182",
#     "monthly_income": "60,000",
#     "income_currency": "SAR"
#   },
#   {
#     "name": "Ananya",
#     "age": "22",
#     "gender": "Female",
#     "address": "Pune",
#     "emp_id": "P-7890-INT",
#     "monthly_income": "80,000",
#     "income_currency": "INR"
#   },
#   {
#     "name": "Marcus",
#     "age": "60",
#     "gender": "Male",
#     "address": "Singapore",
#     "emp_id": "SG-1122",
#     "monthly_income": "30,000",
#     "income_currency": "SGD"
#   }
# ]

# %%
pd.DataFrame([i.model_dump() for i in response.parsed])
# Out:
#       name age  gender    address      emp_id monthly_income income_currency
# 0    Alpha  28    Male      Dubai   -12345678          1.2cr             USD
# 1    Priya  32  Female     Mumbai     E-54321       15 Lakhs             INR
# 2    David  45    Male     London    LON-8899          9,000             GBP
# 3   Fatima  29  Female  Abu Dhabi     AD-765B         40,000             AED
# 4    Kenji  38    Male      Tokyo    TKY-1020    1.5 million             JPY
# 5    Chloe  25  Female     Sydney    SYD-6543         12,000             AUD
# 6      Raj  52    Male  Bangalore     BLR-007         2.5 cr             INR
# 7    Sofia  35  Female   New York   NYC-2024A         25,000             USD
# 8     Omar  41    Male     Riyadh     SA-9182         60,000             SAR
# 9   Ananya  22  Female       Pune  P-7890-INT         80,000             INR
# 10  Marcus  60    Male  Singapore     SG-1122         30,000             SGD

# %%
# by giving instruction inside prompt

# this way is less reliable ,

# extract data from an image
# governmet data from that extract content


from PIL import Image
from google import genai

client = genai.Client()

image = Image.open("/content/Blue and White Modern Technology Article Page A4 Document.png")
#image


# Step 2: Initialize client
client = genai.Client()

# Step 3: Make the API call
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=[image, '''from the given image that contains text , extract all the information that is available as per the given structure
                      'name: str
                      'age: int'
                      'gender: str'
                      'address: str'
                      'aadhaar: str'
                      'monthly_income:  int'
                      'income_currency: str'''
    ],
)

# Step 4: View results
print(response.text)
# Out:
# Here is the extracted information structured as requested:
#
# ```json
# [
#   {
#     "name": "Alpha",
#     "age": 28,
#     "gender": "Male",
#     "address": "Dubai",
#     "aadhaar": "-12345678",
#     "monthly_income": 12000000,
#     "income_currency": "$"
#   },
#   {
#     "name": "Priya",
#     "age": 32,
#     "gender": "Female",
#     "address": "Mumbai",
#     "aadhaar": null,
#     "monthly_income": 1500000,
#     "income_currency": "₹"
#   },
#   {
#     "name": "David",
#     "age": 45,
#     "gender": "Male",
#     "address": "London",
#     "aadhaar": null,
#     "monthly_income": 9000,
#     "income_currency": "£"
#   },
#   {
#     "name": "Fatima",
#     "age": 29,
#     "gender": "Female",
#     "address": "Abu Dhabi",
#     "aadhaar": null,
#     "monthly_income": 40000,
#     "income_currency": "AED"
#   },
#   {
#     "name": "Kenji",
#     "age": 38,
#     "gender": "Male",
#     "address": "Tokyo",
#     "aadhaar": null,
#     "monthly_income": 1500000,
#     "income_currency": "¥"
#   },
#   {
#     "name": "Chloe",
#     "age": 25,
#     "gender": "Female",
#     "address": "Sydney",
#     "aadhaar": null,
#     "monthly_income": 12000,
#     "income_currency": "AUD"
#   },
#   {
#     "name": "Raj",
#     "age": 52,
#     "gender": "Male",
#     "address": "Bangalore",
#     "aadhaar": null,
#     "monthly_income": 25000000,
#     "income_currency": "₹"
#   },
#   {
#     "name": "Sofia",
#     "age": 35,
#     "gender": "Female",
#     "address": "New York",
#     "aadhaar": null,
#     "monthly_income": 25000,
#     "income_currency": "$"
#   },
#   {
#     "name": "Omar",
#     "age": 41,
#     "gender": "Male",
#     "address": "Riyadh",
#     "aadhaar": null,
#     "monthly_income": 60000,
#     "income_currency": "SAR"
#   },
#   {
#     "name": "Ananya",
#     "age": 22,
#     "gender": "Female",
#     "address": "Pune",
#     "aadhaar": null,
#     "monthly_income": 80000,
#     "income_currency": "₹"
#   },
#   {
#     "name": "Marcus",
#     "age": 60,
#     "gender": "Male",
#     "address": "Singapore",
#     "aadhaar": null,
#     "monthly_income": 30000,
#     "income_currency": "SGD"
#   }
# ]
# ```

# %%
# Enum stands for "Enumeration". It is a data type that defines a set of named values — called members or constants — that a variable can take.
    #Think of it like a drop-down menu in a form, where only a few specific choices are allowed.

# %%
# Output.
# pdf :-
   name:-
   dignosis:-
   medicines:-
   final remark:- admit , admittted, stay in hospital

# %%
# admit : admitted
# admitted :admitted
# stay in hospital : admitted

# %%
# problem : country:- continent

import enum


class continent(enum.Enum):
  NORTH_ASIA =  "ASIA"
  SOUTH_ASIA =  "ASIA"
  EAST_ASIA =  "ASIA"
  WEST_ASIA =  "ASIA"
  CENTRAL_ASIA =  "ASIA"
  OTHER = "NOT ASIA"




response = client.models.generate_content(
    model = "gemini-2.5-flash",
    contents="Where is PHOTOSYNTHESIS",
    config={
        "response_mime_type":"text/x.enum",
        "response_schema":continent
    }


)

# %%
print(response.text)
# Out:
# NOT ASIA
